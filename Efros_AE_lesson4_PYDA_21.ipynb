# %% [markdown]
# ## Эфрос Алексей задание 4
# функции

# %%
## Данные
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

# %%
# функция вывода
def input_1():
    while True:
        command = input(f'Введите команду из списка: \n\
    p - узнать владельца документа по его номеру документа; \n\
    s - номеру документа узнать на какой полке он хранится; \n\
    l - полный список хранилица; \n\
    ads - добавить новую полку; \n\
    ds - удалить пустую полку;  \n\
    q - выход. \n\
    \n\n Введите команду: ')
        if command == 'p':
            doc_number = input('Введите номер документа: ')
            print(get_person(doc_number))
        elif command == 's':
            doc_number = input('Введите номер документа: ')
            print(direct_(doc_number))
        elif command == 'l':
            list_all()
       ##     print(list_all())
        elif command == 'ds':
            print(del_shelf(input('Введите номер полки для удаления: ')))
        elif command == 'q':
            print('До свидания')
            break

            
# обработка команды p - узнать владельца документа по его номеру документа
def get_person(doc_number):
    for i in documents:
        if i["number"] == doc_number:
            return f'Владелец документа: {i["name"]}'
            break
    else:
        return 'Документ не найден в базе'

def direct_(doc_number):
 
    if doc_number not in sum(directories.values(), []):
        return 'Документ не найден'
    else:
        for key, value in directories.items():
            if doc_number in value:
                return(f'Документ хранится на полке №{key}')   

            
# обработка комманды  l  вывести реестр            

def list_all():
    for i in documents:
        print(f'Тип документа: {i["type"]}, №: {i["number"]}, владелец: {i["name"]}, {direct_(i["number"])}')

        
# # обработка команды   ads  добавить новую полку       

def add_shelf(shelf_number):
    if shelf_number in directories.keys():
        return f'Такая полка уже существует! {all_shelves()}'
    else:
        while shelf_number != '' and shelf_number != ' ':
            new_directories = {shelf_number: []}
            directories.update(new_directories)
            return f'Добавлена полка №{shelf_number}. {all_shelves()}'
        else:
            return 'Номер полки не может быть пустым значением!'
      
    
# # обработка команды  ds может удалить существующую  пустую полку 

def del_shelf(shelf_number):
    if shelf_number not in directories.keys():
        return 'Такой полки не существует! {all_shelves()}'
    elif shelf_number in directories.keys() and directories[shelf_number] == []:
        del(directories[shelf_number])
        return f'Полка №{shelf_number} удалена. {all_shelves()}'
    else:
        return f'На полке есть документы, удалите их перед удалением полки. {all_shelves()}'

    
# Печать перечня полок для п.п.4, 5   

def all_shelves():
    for i in directories.keys():
        shelves = ', '.join(directories)
        return f'Текущий перечень полок {shelves}'
       
        
    



input_1()
# Out:
# Введите команду из списка:
#     p - узнать владельца документа по его номеру документа;
#     s - номеру документа узнать на какой полке он хранится;
#     l - полный список хранилица;
#     ads - добавить новую полку;
#     ds - удалить пустую полку;
#     q - выход.
#
#
#  Введите команду: l
# Тип документа: passport, №: 2207 876234, владелец: Василий Гупкин, Документ хранится на полке №1
# Тип документа: invoice, №: 11-2, владелец: Геннадий Покемонов, Документ хранится на полке №1
# Тип документа: insurance, №: 10006, владелец: Аристарх Павлов, Документ хранится на полке №2
